# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\beego\Desktop\Visualcode_Courses\STEMACADEMY\streamlit_app\data\HousingPrices_selected.csv')
import numpy as np
from matplotlib.pyplot import hist

# %%
#plot histogram of df
# Out:
# (array([48168,    55,    12,    12,     4,     1,     1,     1,     0,
#             1]),
#  array([1.00000000e+00, 4.86368880e+07, 9.72737750e+07, 1.45910662e+08,
#         1.94547549e+08, 2.43184436e+08, 2.91821323e+08, 3.40458210e+08,
#         3.89095097e+08, 4.37731984e+08, 4.86368871e+08]))

# %%
# Create logarithmic bins
log_bins = np.logspace(np.log10(df['Salgspris'].min()), np.log10(df['Salgspris'].max()), 100)
hist(df['Salgspris'], bins=log_bins);
